# %%
from tensorflow.contrib.learn.python.learn.datasets.mnist import extract_images, extract_labels
import matplotlib.pyplot as plt
import numpy as np

import matplotlib.pyplot as plt
import numpy as np
images = []
import cv2
import glob
for folders in glob.glob("C:\\Users\\Atta\\Desktop\\Neural Network_Datasets\\Deep_Learning_A_Z\\Deep_Learning_A_Z\\Volume 1 - Supervised Deep Learning\Part 2 - Convolutional Neural Networks (CNN)\\Section 8 - Building a CNN\\dataset\\training_set\*"):
    for image in glob.glob(folders+"/*"):
        print(image)
        try:
            img = cv2.imread(image,0)
            images.append(img)
        except:
            continue
    
#images_numpy = np.array(images)
#print(images_numpy.shape)
print(len(images))
print(img.shape)
# Out:
# C:\Users\Atta\Desktop\Neural Network_Datasets\Deep_Learning_A_Z\Deep_Learning_A_Z\Volume 1 - Supervised Deep Learning\Part 2 - Convolutional Neural Networks (CNN)\Section 8 - Building a CNN\dataset\training_set\cats\cat.1.jpg
# C:\Users\Atta\Desktop\Neural Network_Datasets\Deep_Learning_A_Z\Deep_Learning_A_Z\Volume 1 - Supervised Deep Learning\Part 2 - Convolutional Neural Networks (CNN)\Section 8 - Building a CNN\dataset\training_set\cats\cat.10.jpg
# C:\Users\Atta\Desktop\Neural Network_Datasets\Deep_Learning_A_Z\Deep_Learning_A_Z\Volume 1 - Supervised Deep Learning\Part 2 - Convolutional Neural Networks (CNN)\Section 8 - Building a CNN\dataset\training_set\cats\cat.100.jpg
# C:\Users\Atta\Desktop\Neural Network_Datasets\Deep_Learning_A_Z\Deep_Learning_A_Z\Volume 1 - Supervised Deep Learning\Part 2 - Convolutional Neural Networks (CNN)\Section 8 - Building a CNN\dataset\training_set\cats\cat.1000.jpg
# ...

# %%
#converting true labels into one hot encoded format
from keras.utils import to_categorical
encoded = to_categorical(train_labels)
test_encoded = to_categorical(test_labels)
print(encoded[0])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-a820deaf949b> in <module>()
#       1 #converting true labels into one hot encoded format
#       2 from keras.utils import to_categorical
# ----> 3 encoded = to_categorical(train_labels)
#       4 test_encoded = to_categorical(test_labels)
#       5 print(encoded[0])
#
# NameError: name 'train_labels' is not defined
